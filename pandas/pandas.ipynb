# %% [markdown]
# # CRUD operations with dictionaries in python

# %%
import pandas as pd

# %%
# create a data frame from a CSV
df = pd.read_csv('telco_churn.csv')

# %%
# read a data frame

# display first 5 rows of data
df.head()

# display n rows
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# 1             27.47              195.5            103.0             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# 1                13.7                 3                3.7
#
#    Customer service calls  Churn
# 0                     1.0  False
# 1                     1.0  False

# %%
# display bottom rows, n=5 by default
df.tail(8)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3325    OH              78        408                 No              No
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3325                      0              193.4             99.0
# 3326                      0              106.6            128.0
# 3327                      0              134.7             98.0
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3325             32.88              116.9             88.0              9.94
# 3326             18.12              284.8             87.0             24.21
# 3327             22.90              189.7             68.0             16.12
# 3328             26.55              215.5            126.0             18.32
# 3329             39.29              153.4             55.0             13.04
# 3330             30.74              288.8             58.0             24.55
# 3331             36.35              159.6             84.0             13.57
# 3332             39.85              265.9             82.0             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3325                243.3              109.0               10.95
# 3326                178.9               92.0                8.05
# 3327                221.4              128.0                9.96
# 3328                279.1               83.0               12.56
# 3329                191.3              123.0                8.61
# 3330                191.9               91.0                8.64
# 3331                139.2              137.0                6.26
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3325                 9.3                 4               2.51
# 3326                14.9                 7               4.02
# 3327                11.8                 5               3.19
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3325                     2.0  False
# 3326                     1.0  False
# 3327                     2.0  False
# 3328                     2.0  False
# 3329                     3.0  False
# 3330                     2.0  False
# 3331                     2.0  False
# 3332                     0.0  False

# %%
# create a dataframe from a dictionary

# %%
dict = {'col_1': [1, 2, 3], 'col_2': [4, 5, 6], 'col_3': [7, 8, 9]}

# %%
dict_df = pd.DataFrame(dict)
dict_df.head()
# Out:
#    col_1  col_2  col_3
# 0      1      4      7
# 1      2      5      8
# 2      3      6      9

# %%
# show columns
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.State # access a column whose name is without spaces
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df['Account length'] # access a column with spaces in the column name
# Out:
# 0       128
# 1       107
# 2       137
# 3        84
# 4        75
#        ...
# 3328    192
# 3329     68
# 3330     28
# 3331    184
# 3332     74
# Name: Account length, Length: 3333, dtype: int64

# %%
df[['State', 'Account length']] # access multiple columns
# Out:
#      State  Account length
# 0       KS             128
# 1       OH             107
# 2       NJ             137
# 3       OH              84
# 4       OK              75
# ...    ...             ...
# 3328    AZ             192
# 3329    WV              68
# 3330    RI              28
# 3331    CT             184
# 3332    TN              74
#
# [3333 rows x 2 columns]

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# std          20.057356          9.255987          50.676652        19.932115
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.420000         166.600000        87.000000
# 50%         101.000000         30.500000         201.400000       100.000000
# 75%         114.000000         36.780000         235.325000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        Total eve charge  Total night minutes  Total night calls  \
# count       3333.000000          3333.000000        3332.000000
# mean          17.083540           200.872037         100.115246
# std            4.310668            50.573847          19.566710
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.000000          87.000000
# 50%           17.120000           201.200000         100.000000
# 75%           20.000000           235.300000         113.000000
# max           30.910000           395.000000         175.000000
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count         3333.000000         3333.000000       3333.000000
# mean             9.039325           10.237294          4.479448
# std              2.275873            2.791840          2.461214
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.050000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        Total intl charge  Customer service calls
# count        3328.000000             3328.000000
# mean            2.764588                1.563101
# std             0.754086                1.315870
# min             0.000000                0.000000
# 25%             2.300000                1.000000
# 50%             2.780000                1.000000
# 75%             3.270000                2.000000
# max             5.400000                9.000000

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3325
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2842

# %%
df.State.unique() # filter on column
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df[df['International plan'] == 'No'] # conditionally filter on column
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# 6                        24              218.2             88.0
# 8                         0              184.5             97.0
# ...                     ...                ...              ...
# 3327                      0              134.7             98.0
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4             99.0             16.78
# 1                27.47              195.5            103.0             16.62
# 2                41.38              121.2            110.0             10.30
# 6                37.09              348.5            108.0             29.62
# 8                31.37              351.6             80.0             29.89
# ...                ...                ...              ...               ...
# 3327             22.90              189.7             68.0             16.12
# 3328             26.55              215.5            126.0             18.32
# 3329             39.29              153.4             55.0             13.04
# 3330             30.74              288.8             58.0             24.55
# 3332             39.85              265.9             82.0             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7               91.0               11.01
# 1                   254.4              103.0               11.45
# 2                   162.6              104.0                7.32
# 6                   212.6              118.0                9.57
# 8                   215.8               90.0                9.71
# ...                   ...                ...                 ...
# 3327                221.4              128.0                9.96
# 3328                279.1               83.0               12.56
# 3329                191.3              123.0                8.61
# 3330                191.9               91.0                8.64
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 6                    7.5                 7               2.03
# 8                    8.7                 4               2.35
# ...                  ...               ...                ...
# 3327                11.8                 5               3.19
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                        1.0  False
# 1                        1.0  False
# 2                        0.0  False
# 6                        3.0    NaN
# 8                        1.0  False
# ...                      ...    ...
# 3327                     2.0  False
# 3328                     2.0  False
# 3329                     3.0  False
# 3330                     2.0  False
# 3332                     0.0  False
#
# [3010 rows x 20 columns]

# %%
# filter with multiple conditions
# isolate boolean values with parentheses
# use & for AND
df[(df['International plan'] == 'No') & (df.Churn == True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 48      ID             119        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3280    AR              76        408                 No              No
# 3287    KS             170        415                 No             Yes
# 3301    CA              84        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 10                        0              129.1            137.0
# 15                        0                NaN              NaN
# 21                        0                NaN              NaN
# 33                        0              249.6            118.0
# 48                        0              159.1            114.0
# ...                     ...                ...              ...
# 3280                      0              107.3            140.0
# 3287                     42              199.5            119.0
# 3301                      0              280.0            113.0
# 3322                      0              321.1            105.0
# 3323                      0              118.4            126.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 10               21.95              228.5             83.0             19.42
# 15                 NaN              317.8             97.0             27.01
# 21                 NaN              169.9            121.0             14.44
# 33                 NaN                NaN              NaN             21.45
# 48               27.05              231.3            117.0             19.66
# ...                ...                ...              ...               ...
# 3280             18.24              238.2            133.0             20.25
# 3287             33.92              135.0             90.0             11.48
# 3301             47.60              202.2             90.0             17.19
# 3322             54.59              265.5            122.0             22.57
# 3323             20.13              249.3             97.0             21.19
#
#       Total night minutes  Total night calls  Total night charge  \
# 10                  208.8              111.0                9.40
# 15                  160.6              128.0                7.23
# 21                  209.6               64.0                9.43
# 33                  280.2               90.0               12.61
# 48                  143.2               91.0                6.44
# ...                   ...                ...                 ...
# 3280                271.8              116.0               12.23
# 3287                184.6               49.0                8.31
# 3301                156.8              103.0                7.06
# 3322                180.5               72.0                8.12
# 3323                227.0               56.0               10.22
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 10                  12.7                 6               3.43
# 15                   5.4                 9               1.46
# 21                   5.7                 6               1.54
# 33                  11.8                 3               3.19
# 48                   8.8                 3               2.38
# ...                  ...               ...                ...
# 3280                10.0                 3               2.70
# 3287                10.9                 3               2.94
# 3301                10.4                 4               2.81
# 3322                11.5                 2               3.11
# 3323                13.6                 3               3.67
#
#       Customer service calls Churn
# 10                       4.0  True
# 15                       4.0  True
# 21                       5.0  True
# 33                       1.0  True
# 48                       5.0  True
# ...                      ...   ...
# 3280                     4.0  True
# 3287                     4.0  True
# 3301                     0.0  True
# 3322                     4.0  True
# 3323                     5.0  True
#
# [346 rows x 20 columns]

# %%
# iloc method
# integer location based index
df.iloc[14] # access the 15th row of a data frame
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
df.iloc[14, 0] #access the 15th row, first column
# Out:
# 'IA'

# %%
# slicing
df.iloc[22:33] # access rows 22-33, excluding
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 22    AZ             130        415                 No              No
# 23    SC             111        415                 No              No
# 24    VA             132        510                 No              No
# 25    NE             174        415                 No              No
# 26    WY              57        408                 No             Yes
# 27    MT              54        408                 No              No
# 28    MO              20        415                 No              No
# 29    HI              49        510                 No              No
# 30    IL             142        415                 No              No
# 31    NH              75        510                 No              No
# 32    LA             172        408                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 22                      0              183.0            112.0
# 23                      0              110.4            103.0
# 24                      0               81.1             86.0
# 25                      0              124.3             76.0
# 26                     39              213.0            115.0
# 27                      0              134.3             73.0
# 28                      0              190.0            109.0
# 29                      0              119.3            117.0
# 30                      0               84.8             95.0
# 31                      0              226.1            105.0
# 32                      0              212.0            121.0
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 22             31.11               72.9             99.0              6.20
# 23             18.77              137.3            102.0             11.67
# 24             13.79              245.2             72.0             20.84
# 25             21.13              277.1            112.0             23.55
# 26             36.21              191.1            112.0             16.24
# 27             22.83              155.5            100.0             13.22
# 28             32.30              258.2             84.0             21.95
# 29             20.28              215.1            109.0             18.28
# 30             14.42              136.7             63.0             11.62
# 31               NaN                NaN              NaN             17.13
# 32               NaN                NaN              NaN              2.65
#
#     Total night minutes  Total night calls  Total night charge  \
# 22                181.8               78.0                8.18
# 23                189.6              105.0                8.53
# 24                237.0              115.0               10.67
# 25                250.7              115.0               11.28
# 26                182.7              115.0                8.22
# 27                102.1               68.0                4.59
# 28                181.5              102.0                8.17
# 29                178.7               90.0                8.04
# 30                250.5              148.0               11.27
# 31                246.2               98.0               11.08
# 32                293.3               78.0               13.20
#
#     Total intl minutes  Total intl calls  Total intl charge  \
# 22                 9.5                19               2.57
# 23                 7.7                 6               2.08
# 24                10.3                 2               2.78
# 25                15.5                 5               4.19
# 26                 9.5                 3               2.57
# 27                14.7                 4               3.97
# 28                 6.3                 6               1.70
# 29                11.1                 1               3.00
# 30                14.2                 6               3.83
# 31                10.3                 5               2.78
# 32                12.6                10               3.40
#
#     Customer service calls  Churn
# 22                     0.0    NaN
# 23                     2.0  False
# 24                     0.0  False
# 25                     3.0  False
# 26                     0.0  False
# 27                     3.0  False
# 28                     0.0  False
# 29                     1.0    NaN
# 30                     2.0  False
# 31                     1.0  False
# 32                     3.0  False

# %%
state = df.copy()
state.set_index('State', inplace=True) # set a colummn value as index rather than integer
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# KS                45.07              197.4             99.0             16.78
# OH                27.47              195.5            103.0             16.62
# NJ                41.38              121.2            110.0             10.30
# OH                50.90               61.9             88.0              5.26
# OK                28.34              148.3            122.0             12.61
#
#        Total night minutes  Total night calls  Total night charge  \
# State
# KS                   244.7               91.0               11.01
# OH                   254.4              103.0               11.45
# NJ                   162.6              104.0                7.32
# OH                   196.9               89.0                8.86
# OK                   186.9              121.0                8.41
#
#        Total intl minutes  Total intl calls  Total intl charge  \
# State
# KS                   10.0                 3               2.70
# OH                   13.7                 3               3.70
# NJ                   12.2                 5               3.29
# OH                    6.6                 7               1.78
# OK                   10.1                 3               2.73
#
#        Customer service calls  Churn
# State
# KS                        1.0  False
# OH                        1.0  False
# NJ                        0.0  False
# OH                        2.0  False
# OK                        3.0  False

# %%
state.loc['OH'] # filter by location of non-integer value
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                107        415                 No             Yes
# OH                 84        408                Yes              No
# OH                 65        408                 No              No
# OH                 83        415                 No              No
# OH                 63        415                Yes             Yes
# ...               ...        ...                ...             ...
# OH                160        415                 No              No
# OH                 88        408                 No              No
# OH                106        415                 No             Yes
# OH                 78        408                 No              No
# OH                 96        415                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        26              161.6            123.0
# OH                         0              299.4             71.0
# OH                         0              187.9            116.0
# OH                         0              337.4            120.0
# OH                        36              199.0            110.0
# ...                      ...                ...              ...
# OH                         0              206.3             66.0
# OH                         0              274.6            105.0
# OH                        30              220.1            105.0
# OH                         0              193.4             99.0
# OH                         0              106.6            128.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# OH                27.47              195.5            103.0             16.62
# OH                50.90               61.9             88.0              5.26
# OH                31.94              157.6            117.0             13.40
# OH                57.36              227.4            116.0             19.33
# OH                33.83              291.3            111.0             24.76
# ...                 ...                ...              ...               ...
# OH                35.07              241.1            109.0             20.49
# OH                46.68              161.1            121.0             13.69
# OH                37.42              222.2            109.0             18.89
# OH                32.88              116.9             88.0              9.94
# OH                18.12              284.8             87.0             24.21
#
#        Total night minutes  Total night calls  Total night charge  \
# State
# OH                   254.4              103.0               11.45
# OH                   196.9               89.0                8.86
# OH                   227.3               86.0               10.23
# OH                   153.9              114.0                6.93
# OH                   197.6               92.0                8.89
# ...                    ...                ...                 ...
# OH                   227.8              102.0               10.25
# OH                   194.4              123.0                8.75
# OH                   158.4               96.0                7.13
# OH                   243.3              109.0               10.95
# OH                   178.9               92.0                8.05
#
#        Total intl minutes  Total intl calls  Total intl charge  \
# State
# OH                   13.7                 3               3.70
# OH                    6.6                 7               1.78
# OH                    7.5                 6               2.03
# OH                   15.8                 7               4.27
# OH                   11.0                 6               2.97
# ...                   ...               ...                ...
# OH                   11.7                 6               3.16
# OH                    9.2                 4               2.48
# OH                   13.1                 8               3.54
# OH                    9.3                 4               2.51
# OH                   14.9                 7               4.02
#
#        Customer service calls  Churn
# State
# OH                        1.0  False
# OH                        2.0  False
# OH                        1.0  False
# OH                        0.0   True
# OH                        1.0  False
# ...                       ...    ...
# OH                        0.0  False
# OH                        2.0  False
# OH                        0.0  False
# OH                        2.0  False
# OH                        1.0  False
#
# [78 rows x 19 columns]

# %%
df.isnull().sum() # find the total null-value occurrences
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True) # drop null values in place
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.drop('Area code', axis=1) # drop a column along one axis
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# 3                         0              299.4             71.0
# 4                         0              166.7            113.0
# ...                     ...                ...              ...
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4             99.0             16.78
# 1                27.47              195.5            103.0             16.62
# 2                41.38              121.2            110.0             10.30
# 3                50.90               61.9             88.0              5.26
# 4                28.34              148.3            122.0             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5            126.0             18.32
# 3329             39.29              153.4             55.0             13.04
# 3330             30.74              288.8             58.0             24.55
# 3331             36.35              159.6             84.0             13.57
# 3332             39.85              265.9             82.0             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7               91.0               11.01
# 1                   254.4              103.0               11.45
# 2                   162.6              104.0                7.32
# 3                   196.9               89.0                8.86
# 4                   186.9              121.0                8.41
# ...                   ...                ...                 ...
# 3328                279.1               83.0               12.56
# 3329                191.3              123.0                8.61
# 3330                191.9               91.0                8.64
# 3331                139.2              137.0                6.26
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                        1.0  False
# 1                        1.0  False
# 2                        0.0  False
# 3                        2.0  False
# 4                        3.0  False
# ...                      ...    ...
# 3328                     2.0  False
# 3329                     3.0  False
# 3330                     2.0  False
# 3331                     2.0  False
# 3332                     0.0  False
#
# [3307 rows x 19 columns]

# %%
df['New Column'] = df['Total night minutes'] + df['Total intl minutes']

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
# 2             41.38              121.2  ...             10.30
# 3             50.90               61.9  ...              5.26
# 4             28.34              148.3  ...             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn New Column
# 0                     1.0  False      254.7
# 1                     1.0  False      268.1
# 2                     0.0  False      174.8
# 3                     2.0  False      203.5
# 4                     3.0  False      197.0
#
# [5 rows x 21 columns]

# %%
df['New Column'] = 100 # update all rows in column to assigned value
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
# 2             41.38              121.2  ...             10.30
# 3             50.90               61.9  ...              5.26
# 4             28.34              148.3  ...             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn New Column
# 0                     1.0  False        100
# 1                     1.0  False        100
# 2                     0.0  False        100
# 3                     2.0  False        100
# 4                     3.0  False        100
#
# [5 rows x 21 columns]

# %%
df.iloc[0, -1] = 10 # update a value at a particular location
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
# 2             41.38              121.2  ...             10.30
# 3             50.90               61.9  ...              5.26
# 4             28.34              148.3  ...             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn New Column
# 0                     1.0  False         10
# 1                     1.0  False        100
# 2                     0.0  False        100
# 3                     2.0  False        100
# 4                     3.0  False        100
#
# [5 rows x 21 columns]

# %%
# apply method
df['Churn Binary'] = df['Churn'].apply(lambda x: 1 if x==True else 0)
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             27.47              195.5  ...                254.4
# 2             41.38              121.2  ...                162.6
# 3             50.90               61.9  ...                196.9
# 4             28.34              148.3  ...                186.9
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0               91.0               11.01                10.0
# 1              103.0               11.45                13.7
# 2              104.0                7.32                12.2
# 3               89.0                8.86                 6.6
# 4              121.0                8.41                10.1
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3               2.70                     1.0  False
# 1                 3               3.70                     1.0  False
# 2                 5               3.29                     0.0  False
# 3                 7               1.78                     2.0  False
# 4                 3               2.73                     3.0  False
#
#    New Column Churn Binary
# 0          10            0
# 1         100            0
# 2         100            0
# 3         100            0
# 4         100            0
#
# [5 rows x 22 columns]

# %%
# output
df.to_csv('Output.csv')

# %%
df.to_json('Output.json')

# %% [markdown]
# ## Looping over data frames

# %%
data_frame = pd.read_csv('telco_churn.csv', index_col = 0)
print(data_frame)
for lab, row in data_frame.iterrows():
    print(lab)
    print(row)
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
# ...               ...        ...                ...             ...
# AZ                192        415                 No             Yes
# WV                 68        415                 No              No
# RI                 28        510                 No              No
# CT                184        510                Yes              No
# TN                 74        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
# ...                      ...                ...              ...
# AZ                        36              156.2             77.0
# WV                         0              231.1             57.0
# RI                         0              180.8            109.0
# CT                         0              213.8            105.0
# TN                        25              234.4            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# KS                45.07              197.4             99.0             16.78
# OH                27.47              195.5            103.0             16.62
# NJ                41.38              121.2            110.0             10.30
# OH                50.90               61.9             88.0              5.26
# OK                28.34              148.3            122.0             12.61
# ...                 ...                ...              ...               ...
# AZ                26.55              215.5            126.0             18.32
# WV                39.29              153.4             55.0             13.04
# RI                30.74              288.8             58.0             24.55
# CT                36.35              159.6             84.0             13.57
# TN                39.85              265.9             82.0             22.60
#
#        Total night minutes  Total night calls  Total night charge  \
# State
# KS                   244.7               91.0               11.01
# OH                   254.4              103.0               11.45
# NJ                   162.6              104.0                7.32
# OH                   196.9               89.0                8.86
# OK                   186.9              121.0                8.41
# ...                    ...                ...                 ...
# AZ                   279.1               83.0               12.56
# WV                   191.3              123.0                8.61
# RI                   191.9               91.0                8.64
# CT                   139.2              137.0                6.26
# TN                   241.4               77.0               10.86
#
#        Total intl minutes  Total intl calls  Total intl charge  \
# State
# KS                   10.0                 3               2.70
# OH                   13.7                 3               3.70
# NJ                   12.2                 5               3.29
# OH                    6.6                 7               1.78
# OK                   10.1                 3               2.73
# ...                   ...               ...                ...
# AZ                    9.9                 6               2.67
# WV                    9.6                 4               2.59
# RI                   14.1                 6               3.81
# CT                    5.0                10               1.35
# TN                   13.7                 4               3.70
#
#        Customer service calls  Churn
# State
# KS                        1.0  False
# OH                        1.0  False
# NJ                        0.0  False
# OH                        2.0  False
# OK                        3.0  False
# ...                       ...    ...
# AZ                        2.0  False
# WV                        3.0  False
# RI                        2.0  False
# CT                        2.0  False
# TN                        0.0  False
#
# [3333 rows x 19 columns]
# KS
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         265.1
# Total day calls           110.0
# Total day charge          45.07
# Total eve minutes         197.4
# Total eve calls            99.0
# Total eve charge          16.78
# Total night minutes       244.7
# Total night calls          91.0
# Total night charge        11.01
# Total intl minutes         10.0
# Total intl calls              3
# Total intl charge           2.7
# Customer service calls      1.0
# Churn                     False
# Name: KS, dtype: object
# OH
# Account length              107
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        26
# Total day minutes         161.6
# Total day calls           123.0
# Total day charge          27.47
# Total eve minutes         195.5
# Total eve calls           103.0
# Total eve charge          16.62
# Total night minutes       254.4
# Total night calls         103.0
# Total night charge        11.45
# Total intl minutes         13.7
# Total intl calls              3
# Total intl charge           3.7
# Customer service calls      1.0
# Churn                     False
# Name: OH, dtype: object
# NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls           114.0
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls           110.0
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls         104.0
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls      0.0
# Churn                     False
# Name: NJ, dtype: object
# OH
# Account length               84
# Area code                   408
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         299.4
# Total day calls            71.0
# Total day charge           50.9
# Total eve minutes          61.9
# Total eve calls            88.0
# Total eve charge           5.26
# Total night minutes       196.9
# Total night calls          89.0
# Total night charge         8.86
# Total intl minutes          6.6
# Total intl calls              7
# Total intl charge          1.78
# Customer service calls      2.0
# Churn                     False
# Name: OH, dtype: object
# OK
# Account length               75
# Area code                   415
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         166.7
# Total day calls           113.0
# Total day charge          28.34
# Total eve minutes         148.3
# Total eve calls           122.0
# Total eve charge          12.61
# Total night minutes       186.9
# Total night calls         121.0
# Total night charge         8.41
# Total intl minutes         10.1
# Total intl calls              3
# Total intl charge          2.73
# Customer service calls      3.0
# Churn                     False
# Name: OK, dtype: object
# AL
# Account length              118
# Area code                   510
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         223.4
# Total day calls            98.0
# Total day charge          37.98
# Total eve minutes         220.6
# Total eve calls           101.0
# Total eve charge          18.75
# Total night minutes       203.9
# Total night calls         118.0
# Total night charge         9.18
# Total intl minutes          6.3
# Total intl calls              6
# Total intl charge           1.7
# Customer service calls      0.0
# Churn                     False
# Name: AL, dtype: object
# MA
# Account length              121
# Area code                   510
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        24
# Total day minutes         218.2
# Total day calls            88.0
# Total day charge          37.09
# Total eve minutes         348.5
# Total eve calls           108.0
# Total eve charge          29.62
# Total night minutes       212.6
# Total night calls         118.0
# Total night charge         9.57
# Total intl minutes          7.5
# Total intl calls              7
# Total intl charge          2.03
# Customer service calls      3.0
# Churn                       NaN
# Name: MA, dtype: object
# MO
# Account length              147
# Area code                   415
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         157.0
# Total day calls            79.0
# Total day charge          26.69
# Total eve minutes         103.1
# Total eve calls            94.0
# Total eve charge           8.76
# Total night minutes       211.8
# Total night calls          96.0
# Total night charge         9.53
# Total intl minutes          7.1
# Total intl calls              6
# Total intl charge          1.92
# Customer service calls      0.0
# Churn                     False
# Name: MO, dtype: object
# LA
# Account length              117
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         184.5
# Total day calls            97.0
# Total day charge          31.37
# Total eve minutes         351.6
# Total eve calls            80.0
# Total eve charge          29.89
# Total night minutes       215.8
# Total night calls          90.0
# Total night charge         9.71
# Total intl minutes          8.7
# Total intl calls              4
# Total intl charge          2.35
# Customer service calls      1.0
# Churn                     False
# Name: LA, dtype: object
# WV
# Account length              141
# Area code                   415
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        37
# Total day minutes         258.6
# Total day calls            84.0
# Total day charge          43.96
# Total eve minutes         222.0
# Total eve calls           111.0
# Total eve charge          18.87
# Total night minutes       326.4
# Total night calls          97.0
# Total night charge        14.69
# Total intl minutes         11.2
# Total intl calls              5
# Total intl charge          3.02
# Customer service calls      0.0
# Churn                     False
# Name: WV, dtype: object
# IN
# Account length               65
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         129.1
# Total day calls           137.0
# Total day charge          21.95
# Total eve minutes         228.5
# Total eve calls            83.0
# Total eve charge          19.42
# Total night minutes       208.8
# Total night calls         111.0
# Total night charge          9.4
# Total intl minutes         12.7
# Total intl calls              6
# Total intl charge          3.43
# Customer service calls      4.0
# Churn                      True
# Name: IN, dtype: object
# RI
# Account length               74
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         187.7
# Total day calls           127.0
# Total day charge          31.91
# Total eve minutes         163.4
# Total eve calls           148.0
# Total eve charge          13.89
# Total night minutes       196.0
# Total night calls          94.0
# Total night charge         8.82
# Total intl minutes          9.1
# Total intl calls              5
# Total intl charge          2.46
# Customer service calls      0.0
# Churn                     False
# Name: RI, dtype: object
# IA
# Account length              168
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         104.9
# Total eve calls            71.0
# Total eve charge           8.92
# Total night minutes       141.1
# Total night calls         128.0
# Total night charge         6.35
# Total intl minutes         11.2
# Total intl calls              2
# Total intl charge          3.02
# Customer service calls      1.0
# Churn                     False
# Name: IA, dtype: object
# MT
# Account length               95
# Area code                   510
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         247.6
# Total eve calls            75.0
# Total eve charge          21.05
# Total night minutes       192.3
# Total night calls         115.0
# Total night charge         8.65
# Total intl minutes         12.3
# Total intl calls              5
# Total intl charge          3.32
# Customer service calls      3.0
# Churn                     False
# Name: MT, dtype: object
# IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: IA, dtype: object
# NY
# Account length              161
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         317.8
# Total eve calls            97.0
# Total eve charge          27.01
# Total night minutes       160.6
# Total night calls         128.0
# Total night charge         7.23
# Total intl minutes          5.4
# Total intl calls              9
# Total intl charge          1.46
# Customer service calls      4.0
# Churn                      True
# Name: NY, dtype: object
# ID
# Account length               85
# Area code                   408
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        27
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         280.9
# Total eve calls            90.0
# Total eve charge          23.88
# Total night minutes        89.3
# Total night calls           NaN
# Total night charge         4.02
# Total intl minutes         13.8
# Total intl calls              4
# Total intl charge          3.73
# Customer service calls      1.0
# Churn                     False
# Name: ID, dtype: object
# VT
# Account length               93
# Area code                   510
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         218.2
# Total eve calls           111.0
# Total eve charge          18.55
# Total night minutes       129.6
# Total night calls         121.0
# Total night charge         5.83
# Total intl minutes          8.1
# Total intl calls              3
# Total intl charge          2.19
# Customer service calls      3.0
# Churn                     False
# Name: VT, dtype: object
# VA
# Account length               76
# Area code                   510
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        33
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         212.8
# Total eve calls            65.0
# Total eve charge          18.09
# Total night minutes       165.7
# Total night calls         108.0
# Total night charge         7.46
# Total intl minutes         10.0
# Total intl calls              5
# Total intl charge           2.7
# Customer service calls      1.0
# Churn                     False
# Name: VA, dtype: object
# TX
# Account length               73
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes           NaN
# Total eve calls            88.0
# Total eve charge          13.56
# Total night minutes       192.8
# Total night calls          74.0
# Total night charge         8.68
# Total intl minutes         13.0
# Total intl calls              2
# Total intl charge          3.51
# Customer service calls      1.0
# Churn                     False
# Name: TX, dtype: object
# FL
# Account length              147
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         239.7
# Total eve calls            93.0
# Total eve charge          20.37
# Total night minutes       208.8
# Total night calls         133.0
# Total night charge          9.4
# Total intl minutes         10.6
# Total intl calls              4
# Total intl charge          2.86
# Customer service calls      0.0
# Churn                     False
# Name: FL, dtype: object
# CO
# Account length               77
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         169.9
# Total eve calls           121.0
# Total eve charge          14.44
# Total night minutes       209.6
# Total night calls          64.0
# Total night charge         9.43
# Total intl minutes          5.7
# Total intl calls              6
# Total intl charge          1.54
# Customer service calls      5.0
# Churn                      True
# Name: CO, dtype: object
# AZ
# Account length              130
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         183.0
# Total day calls           112.0
# Total day charge          31.11
# Total eve minutes          72.9
# Total eve calls            99.0
# Total eve charge            6.2
# Total night minutes       181.8
# Total night calls          78.0
# Total night charge         8.18
# Total intl minutes          9.5
# Total intl calls             19
# Total intl charge          2.57
# Customer service calls      0.0
# Churn                       NaN
# Name: AZ, dtype: object
# SC
# Account length              111
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         110.4
# Total day calls           103.0
# Total day charge          18.77
# Total eve minutes         137.3
# Total eve calls           102.0
# Total eve charge          11.67
# Total night minutes       189.6
# Total night calls         105.0
# Total night charge         8.53
# Total intl minutes          7.7
# Total intl calls              6
# Total intl charge          2.08
# Customer service calls      2.0
# Churn                     False
# Name: SC, dtype: object
# VA
# Account length              132
# Area code                   510
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes          81.1
# Total day calls            86.0
# Total day charge          13.79
# Total eve minutes         245.2
# Total eve calls            72.0
# Total eve charge          20.84
# Total night minutes       237.0
# Total night calls         115.0
# Total night charge        10.67
# Total intl minutes         10.3
# Total intl calls              2
# Total intl charge          2.78
# Customer service calls      0.0
# Churn                     False
# Name: VA, dtype: object
# NE
# Account length              174
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         124.3
# Total day calls            76.0
# Total day charge          21.13
# Total eve minutes         277.1
# Total eve calls           112.0
# Total eve charge          23.55
# Total night minutes       250.7
# Total night calls         115.0
# Total night charge        11.28
# Total intl minutes         15.5
# Total intl calls              5
# Total intl charge          4.19
# Customer service calls      3.0
# Churn                     False
# Name: NE, dtype: object
# WY
# Account length               57
# Area code                   408
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        39
# Total day minutes         213.0
# Total day calls           115.0
# Total day charge          36.21
# Total eve minutes         191.1
# Total eve calls           112.0
# Total eve charge          16.24
# Total night minutes       182.7
# Total night calls         115.0
# Total night charge         8.22
# Total intl minutes          9.5
# Total intl calls              3
# Total intl charge          2.57
# Customer service calls      0.0
# Churn                     False
# Name: WY, dtype: object
# MT
# Account length               54
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         134.3
# Total day calls            73.0
# Total day charge          22.83
# Total eve minutes         155.5
# Total eve calls           100.0
# Total eve charge          13.22
# Total night minutes       102.1
# Total night calls          68.0
# Total night charge         4.59
# Total intl minutes         14.7
# Total intl calls              4
# Total intl charge          3.97
# Customer service calls      3.0
# Churn                     False
# Name: MT, dtype: object
# MO
# Account length               20
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         190.0
# Total day calls           109.0
# Total day charge           32.3
# Total eve minutes         258.2
# Total eve calls            84.0
# Total eve charge          21.95
# Total night minutes       181.5
# Total night calls         102.0
# Total night charge         8.17
# Total intl minutes          6.3
# Total intl calls              6
# Total intl charge           1.7
# Customer service calls      0.0
# Churn                     False
# Name: MO, dtype: object
# HI
# Account length               49
# Area code                   510
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         119.3
# Total day calls           117.0
# Total day charge          20.28
# Total eve minutes         215.1
# Total eve calls           109.0
# Total eve charge          18.28
# Total night minutes       178.7
# Total night calls          90.0
# Total night charge         8.04
# Total intl minutes         11.1
# Total intl calls              1
# Total intl charge           3.0
# Customer service calls      1.0
# Churn                       NaN
# Name: HI, dtype: object
# IL
# Account length              142
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes          84.8
# Total day calls            95.0
# Total day charge          14.42
# Total eve minutes         136.7
# Total eve calls            63.0
# Total eve charge          11.62
# Total night minutes       250.5
# Total night calls         148.0
# Total night charge        11.27
# Total intl minutes         14.2
# Total intl calls              6
# Total intl charge          3.83
# Customer service calls      2.0
# Churn                     False
# Name: IL, dtype: object
# NH
# Account length               75
# Area code                   510
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         226.1
# Total day calls           105.0
# Total day charge            NaN
# Total eve minutes           NaN
# Total eve calls             NaN
# Total eve charge          17.13
# Total night minutes       246.2
# Total night calls          98.0
# Total night charge        11.08
# Total intl minutes         10.3
# Total intl calls              5
# Total intl charge          2.78
# Customer service calls      1.0
# Churn                     False
# Name: NH, dtype: object
# LA
# Account length              172
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         212.0
# Total day calls           121.0
# Total day charge            NaN
# Total eve minutes           NaN
# Total eve calls             NaN
# Total eve charge           2.65
# Total night minutes       293.3
# Total night calls          78.0
# Total night charge         13.2
# Total intl minutes         12.6
# Total intl calls             10
# Total intl charge           3.4
# Customer service calls      3.0
# Churn                     False
# Name: LA, dtype: object
# AZ
# Account length               12
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         249.6
# Total day calls           118.0
# Total day charge            NaN
# Total eve minutes           NaN
# Total eve calls             NaN
# Total eve charge          21.45
# Total night minutes       280.2
# Total night calls          90.0
# Total night charge        12.61
# Total intl minutes         11.8
# Total intl calls              3
# Total intl charge          3.19
# Customer service calls      1.0
# Churn                      True
# Name: AZ, dtype: object
# OK
# Account length               57
# Area code                   408
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         176.8
# Total day calls            94.0
# Total day charge            NaN
# Total eve minutes           NaN
# Total eve calls             NaN
# Total eve charge          16.58
# Total night minutes       213.5
# Total night calls         116.0
# Total night charge         9.61
# Total intl minutes          8.3
# Total intl calls              4
# Total intl charge          2.24
# Customer service calls      0.0
# Churn                     False
# Name: OK, dtype: object
# GA
# Account length               72
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        37
# Total day minutes         220.0
# Total day calls            80.0
# Total day charge            NaN
# Total eve minutes           NaN
# Total eve calls             NaN
# Total eve charge          18.47
# Total night minutes       152.8
# Total night calls          71.0
# Total night charge         6.88
# Total intl minutes         14.7
# Total intl calls              6
# Total intl charge          3.97
# Customer service calls      3.0
# Churn                     False
# Name: GA, dtype: object
# AK
# Account length               36
# Area code                   408
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        30
# Total day minutes         146.3
# Total day calls           128.0
# Total day charge            NaN
# Total eve minutes           NaN
# Total eve calls             NaN
# Total eve charge          13.81
# Total night minutes       129.3
# Total night calls         109.0
# Total night charge         5.82
# Total intl minutes         14.5
# Total intl calls              6
# Total intl charge          3.92
# Customer service calls      0.0
# Churn                     False
# Name: AK, dtype: object
# MA
# Account length               78
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         130.8
# Total day calls            64.0
# Total day charge            NaN
# Total eve minutes           NaN
# Total eve calls             NaN
# Total eve charge          19.01
# Total night minutes       227.8
# Total night calls         108.0
# Total night charge        10.25
# Total intl minutes         10.0
# Total intl calls              5
# Total intl charge           2.7
# Customer service calls      1.0
# Churn                     False
# Name: MA, dtype: object
# AK
# Account length              136
# Area code                   415
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        33
# Total day minutes         203.9
# Total day calls           106.0
# Total day charge            NaN
# Total eve minutes           NaN
# Total eve calls             NaN
# Total eve charge          15.95
# Total night minutes       101.7
# Total night calls         107.0
# Total night charge         4.58
# Total intl minutes         10.5
# Total intl calls              6
# Total intl charge          2.84
# Customer service calls      3.0
# Churn                     False
# Name: AK, dtype: object
# NJ
# Account length              149
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         140.4
# Total day calls            94.0
# Total day charge          23.87
# Total eve minutes         271.8
# Total eve calls            92.0
# Total eve charge           23.1
# Total night minutes       188.3
# Total night calls         108.0
# Total night charge         8.47
# Total intl minutes         11.1
# Total intl calls              9
# Total intl charge           3.0
# Customer service calls      1.0
# Churn                     False
# Name: NJ, dtype: object
# GA
# Account length               98
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         126.3
# Total day calls           102.0
# Total day charge          21.47
# Total eve minutes         166.8
# Total eve calls            85.0
# Total eve charge          14.18
# Total night minutes       187.8
# Total night calls         135.0
# Total night charge         8.45
# Total intl minutes          9.4
# Total intl calls              2
# Total intl charge          2.54
# Customer service calls      3.0
# Churn                     False
# Name: GA, dtype: object
# MD
# Account length              135
# Area code                   408
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        41
# Total day minutes         173.1
# Total day calls            85.0
# Total day charge          29.43
# Total eve minutes         203.9
# Total eve calls           107.0
# Total eve charge          17.33
# Total night minutes       122.2
# Total night calls          78.0
# Total night charge          5.5
# Total intl minutes         14.6
# Total intl calls             15
# Total intl charge          3.94
# Customer service calls      0.0
# Churn                      True
# Name: MD, dtype: object
# AR
# Account length               34
# Area code                   510
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         124.8
# Total day calls            82.0
# Total day charge          21.22
# Total eve minutes         282.2
# Total eve calls            98.0
# Total eve charge          23.99
# Total night minutes       311.5
# Total night calls          78.0
# Total night charge        14.02
# Total intl minutes         10.0
# Total intl calls              4
# Total intl charge           2.7
# Customer service calls      2.0
# Churn                     False
# Name: AR, dtype: object
# ID
# Account length              160
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes          85.8
# Total day calls            77.0
# Total day charge          14.59
# Total eve minutes         165.3
# Total eve calls           110.0
# Total eve charge          14.05
# Total night minutes       178.5
# Total night calls          92.0
# Total night charge         8.03
# Total intl minutes          9.2
# Total intl calls              4
# Total intl charge          2.48
# Customer service calls      3.0
# Churn                     False
# Name: ID, dtype: object
# WI
# Account length               64
# Area code                   510
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         154.0
# Total day calls            67.0
# Total day charge          26.18
# Total eve minutes         225.8
# Total eve calls           118.0
# Total eve charge          19.19
# Total night minutes       265.3
# Total night calls          86.0
# Total night charge        11.94
# Total intl minutes          3.5
# Total intl calls              3
# Total intl charge          0.95
# Customer service calls      1.0
# Churn                     False
# Name: WI, dtype: object
# OR
# Account length               59
# Area code                   408
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        28
# Total day minutes         120.9
# Total day calls            97.0
# Total day charge          20.55
# Total eve minutes         213.0
# Total eve calls            92.0
# Total eve charge          18.11
# Total night minutes       163.1
# Total night calls         116.0
# Total night charge         7.34
# Total intl minutes          8.5
# Total intl calls              5
# Total intl charge           2.3
# Customer service calls      2.0
# Churn                     False
# Name: OR, dtype: object
# MI
# Account length               65
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         211.3
# Total day calls           120.0
# Total day charge          35.92
# Total eve minutes         162.6
# Total eve calls           122.0
# Total eve charge          13.82
# Total night minutes       134.7
# Total night calls         118.0
# Total night charge         6.06
# Total intl minutes         13.2
# Total intl calls              5
# Total intl charge          3.56
# Customer service calls      3.0
# Churn                     False
# Name: MI, dtype: object
# DE
# Account length              142
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         187.0
# Total day calls           133.0
# Total day charge          31.79
# Total eve minutes         134.6
# Total eve calls            74.0
# Total eve charge          11.44
# Total night minutes       242.2
# Total night calls         127.0
# Total night charge         10.9
# Total intl minutes          7.4
# Total intl calls              5
# Total intl charge           2.0
# Customer service calls      2.0
# Churn                     False
# Name: DE, dtype: object
# ID
# Account length              119
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         159.1
# Total day calls           114.0
# Total day charge          27.05
# Total eve minutes         231.3
# Total eve calls           117.0
# Total eve charge          19.66
# Total night minutes       143.2
# Total night calls          91.0
# Total night charge         6.44
# Total intl minutes          8.8
# Total intl calls              3
# Total intl charge          2.38
# Customer service calls      5.0
# Churn                      True
# Name: ID, dtype: object
# WY
# Account length               97
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        24
# Total day minutes         133.2
# Total day calls           135.0
# Total day charge          22.64
# Total eve minutes         217.2
# Total eve calls            58.0
# Total eve charge          18.46
# Total night minutes        70.6
# Total night calls          79.0
# Total night charge         3.18
# Total intl minutes         11.0
# Total intl calls              3
# Total intl charge          2.97
# Customer service calls      1.0
# Churn                     False
# Name: WY, dtype: object
# IA
# Account length               52
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         191.9
# Total day calls           108.0
# Total day charge          32.62
# Total eve minutes         269.8
# Total eve calls            96.0
# Total eve charge          22.93
# Total night minutes       236.8
# Total night calls          87.0
# Total night charge        10.66
# Total intl minutes          7.8
# Total intl calls              5
# Total intl charge          2.11
# Customer service calls      3.0
# Churn                     False
# Name: IA, dtype: object
# IN
# Account length               60
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         220.6
# Total day calls            57.0
# Total day charge           37.5
# Total eve minutes         211.1
# Total eve calls           115.0
# Total eve charge          17.94
# Total night minutes       249.0
# Total night calls         129.0
# Total night charge        11.21
# Total intl minutes          6.8
# Total intl calls              3
# Total intl charge          1.84
# Customer service calls      1.0
# Churn                     False
# Name: IN, dtype: object
# VA
# Account length               10
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         186.1
# Total day calls           112.0
# Total day charge          31.64
# Total eve minutes         190.2
# Total eve calls            66.0
# Total eve charge          16.17
# Total night minutes       282.8
# Total night calls          57.0
# Total night charge        12.73
# Total intl minutes         11.4
# Total intl calls              6
# Total intl charge          3.08
# Customer service calls      2.0
# Churn                     False
# Name: VA, dtype: object
# UT
# Account length               96
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         160.2
# Total day calls           117.0
# Total day charge          27.23
# Total eve minutes         267.5
# Total eve calls            67.0
# Total eve charge          22.74
# Total night minutes       228.5
# Total night calls          68.0
# Total night charge        10.28
# Total intl minutes          9.3
# Total intl calls              5
# Total intl charge          2.51
# Customer service calls      2.0
# Churn                     False
# Name: UT, dtype: object
# WY
# Account length               87
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         151.0
# Total day calls            83.0
# Total day charge          25.67
# Total eve minutes         219.7
# Total eve calls           116.0
# Total eve charge          18.67
# Total night minutes       203.9
# Total night calls         127.0
# Total night charge         9.18
# Total intl minutes          9.7
# Total intl calls              3
# Total intl charge          2.62
# Customer service calls      5.0
# Churn                      True
# Name: WY, dtype: object
# IN
# Account length               81
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         175.5
# Total day calls            67.0
# Total day charge          29.84
# Total eve minutes         249.3
# Total eve calls            85.0
# Total eve charge          21.19
# Total night minutes       270.2
# Total night calls          98.0
# Total night charge        12.16
# Total intl minutes         10.2
# Total intl calls              3
# Total intl charge          2.75
# Customer service calls      1.0
# Churn                     False
# Name: IN, dtype: object
# CO
# Account length              141
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         126.9
# Total day calls            98.0
# Total day charge          21.57
# Total eve minutes         180.0
# Total eve calls            62.0
# Total eve charge           15.3
# Total night minutes       140.8
# Total night calls         128.0
# Total night charge         6.34
# Total intl minutes          8.0
# Total intl calls              2
# Total intl charge          2.16
# Customer service calls      1.0
# Churn                     False
# Name: CO, dtype: object
# CO
# Account length              121
# Area code                   408
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        30
# Total day minutes         198.4
# Total day calls           129.0
# Total day charge          33.73
# Total eve minutes          75.3
# Total eve calls            77.0
# Total eve charge            6.4
# Total night minutes       181.2
# Total night calls          77.0
# Total night charge         8.15
# Total intl minutes          5.8
# Total intl calls              3
# Total intl charge          1.57
# Customer service calls      3.0
# Churn                      True
# Name: CO, dtype: object
# WI
# Account length               68
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         148.8
# Total day calls            70.0
# Total day charge           25.3
# Total eve minutes         246.5
# Total eve calls           164.0
# Total eve charge          20.95
# Total night minutes       129.8
# Total night calls         103.0
# Total night charge         5.84
# Total intl minutes         12.1
# Total intl calls              3
# Total intl charge          3.27
# Customer service calls      3.0
# Churn                     False
# Name: WI, dtype: object
# OK
# Account length              125
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         229.3
# Total day calls           103.0
# Total day charge          38.98
# Total eve minutes         177.4
# Total eve calls           126.0
# Total eve charge          15.08
# Total night minutes       189.3
# Total night calls          95.0
# Total night charge         8.52
# Total intl minutes         12.0
# Total intl calls              8
# Total intl charge          3.24
# Customer service calls      1.0
# Churn                     False
# Name: OK, dtype: object
# ID
# Account length              174
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         192.1
# Total day calls            97.0
# Total day charge          32.66
# Total eve minutes         169.9
# Total eve calls            94.0
# Total eve charge          14.44
# Total night minutes       166.6
# Total night calls          54.0
# Total night charge          7.5
# Total intl minutes         11.4
# Total intl calls              4
# Total intl charge          3.08
# Customer service calls      1.0
# Churn                     False
# Name: ID, dtype: object
# CA
# Account length              116
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        34
# Total day minutes         268.6
# Total day calls            83.0
# Total day charge          45.66
# Total eve minutes         178.2
# Total eve calls           142.0
# Total eve charge          15.15
# Total night minutes       166.3
# Total night calls         106.0
# Total night charge         7.48
# Total intl minutes         11.6
# Total intl calls              3
# Total intl charge          3.13
# Customer service calls      2.0
# Churn                     False
# Name: CA, dtype: object
# MN
# Account length               74
# Area code                   510
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        33
# Total day minutes         193.7
# Total day calls            91.0
# Total day charge          32.93
# Total eve minutes         246.1
# Total eve calls            96.0
# Total eve charge          20.92
# Total night minutes       138.0
# Total night calls          92.0
# Total night charge         6.21
# Total intl minutes         14.6
# Total intl calls              3
# Total intl charge          3.94
# Customer service calls      2.0
# Churn                     False
# Name: MN, dtype: object
# SD
# Account length              149
# Area code                   408
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        28
# Total day minutes         180.7
# Total day calls            92.0
# Total day charge          30.72
# Total eve minutes         187.8
# Total eve calls            64.0
# Total eve charge          15.96
# Total night minutes       265.5
# Total night calls          53.0
# Total night charge        11.95
# Total intl minutes         12.6
# Total intl calls              3
# Total intl charge           3.4
# Customer service calls      3.0
# Churn                     False
# Name: SD, dtype: object
# NC
# Account length               38
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         131.2
# Total day calls            98.0
# Total day charge           22.3
# Total eve minutes         162.9
# Total eve calls            97.0
# Total eve charge          13.85
# Total night minutes       159.0
# Total night calls         106.0
# Total night charge         7.15
# Total intl minutes          8.2
# Total intl calls              6
# Total intl charge          2.21
# Customer service calls      2.0
# Churn                     False
# Name: NC, dtype: object
# WA
# Account length               40
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        41
# Total day minutes         148.1
# Total day calls            74.0
# Total day charge          25.18
# Total eve minutes         169.5
# Total eve calls            88.0
# Total eve charge          14.41
# Total night minutes       214.1
# Total night calls         102.0
# Total night charge         9.63
# Total intl minutes          6.2
# Total intl calls              5
# Total intl charge          1.67
# Customer service calls      2.0
# Churn                     False
# Name: WA, dtype: object
# WY
# Account length               43
# Area code                   415
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         251.5
# Total day calls           105.0
# Total day charge          42.76
# Total eve minutes         212.8
# Total eve calls           104.0
# Total eve charge          18.09
# Total night minutes       157.8
# Total night calls          67.0
# Total night charge          7.1
# Total intl minutes          9.3
# Total intl calls              4
# Total intl charge          2.51
# Customer service calls      0.0
# Churn                     False
# Name: WY, dtype: object
# MN
# Account length              113
# Area code                   408
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         125.2
# Total day calls            93.0
# Total day charge          21.28
# Total eve minutes         206.4
# ...
# Total intl charge          4.81
# Customer service calls      4.0
# Churn                     False
# Name: OK, dtype: object
# IA
# Account length               45
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         211.3
# Total day calls            87.0
# Total day charge          35.92
# Total eve minutes         165.7
# Total eve calls            97.0
# Total eve charge          14.08
# Total night minutes       265.9
# Total night calls          72.0
# Total night charge        11.97
# Total intl minutes         13.3
# Total intl calls              6
# Total intl charge          3.59
# Customer service calls      1.0
# Churn                     False
# Name: IA, dtype: object
# VT
# Account length              100
# Area code                   408
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         219.4
# Total day calls           112.0
# Total day charge           37.3
# Total eve minutes         225.7
# Total eve calls           102.0
# Total eve charge          19.18
# Total night minutes       255.3
# Total night calls          95.0
# Total night charge        11.49
# Total intl minutes         12.0
# Total intl calls              4
# Total intl charge          3.24
# Customer service calls      4.0
# Churn                     False
# Name: VT, dtype: object
# NY
# Account length               94
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         190.4
# Total day calls            91.0
# Total day charge          32.37
# Total eve minutes          92.0
# Total eve calls           107.0
# Total eve charge           7.82
# Total night minutes       224.8
# Total night calls         108.0
# Total night charge        10.12
# Total intl minutes         13.6
# Total intl calls             17
# Total intl charge          3.67
# Customer service calls      2.0
# Churn                     False
# Name: NY, dtype: object
# LA
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         147.7
# Total day calls            94.0
# Total day charge          25.11
# Total eve minutes         283.3
# Total eve calls            83.0
# Total eve charge          24.08
# Total night minutes       188.3
# Total night calls         124.0
# Total night charge         8.47
# Total intl minutes          6.9
# Total intl calls              5
# Total intl charge          1.86
# Customer service calls      2.0
# Churn                     False
# Name: LA, dtype: object
# SC
# Account length              181
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         229.9
# Total day calls           130.0
# Total day charge          39.08
# Total eve minutes         144.4
# Total eve calls            93.0
# Total eve charge          12.27
# Total night minutes       262.4
# Total night calls         110.0
# Total night charge        11.81
# Total intl minutes         14.2
# Total intl calls              4
# Total intl charge          3.83
# Customer service calls      2.0
# Churn                     False
# Name: SC, dtype: object
# ID
# Account length              127
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         102.8
# Total day calls           128.0
# Total day charge          17.48
# Total eve minutes         143.7
# Total eve calls            95.0
# Total eve charge          12.21
# Total night minutes       191.4
# Total night calls          97.0
# Total night charge         8.61
# Total intl minutes         10.0
# Total intl calls              5
# Total intl charge           2.7
# Customer service calls      1.0
# Churn                     False
# Name: ID, dtype: object
# MO
# Account length               89
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         178.7
# Total day calls            81.0
# Total day charge          30.38
# Total eve minutes         233.7
# Total eve calls            74.0
# Total eve charge          19.86
# Total night minutes       131.9
# Total night calls         120.0
# Total night charge         5.94
# Total intl minutes          9.1
# Total intl calls              4
# Total intl charge          2.46
# Customer service calls      1.0
# Churn                     False
# Name: MO, dtype: object
# ME
# Account length              149
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        18
# Total day minutes         148.5
# Total day calls           106.0
# Total day charge          25.25
# Total eve minutes         114.5
# Total eve calls           106.0
# Total eve charge           9.73
# Total night minutes       178.3
# Total night calls          98.0
# Total night charge         8.02
# Total intl minutes          6.5
# Total intl calls              4
# Total intl charge          1.76
# Customer service calls      0.0
# Churn                     False
# Name: ME, dtype: object
# MS
# Account length              103
# Area code                   510
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        29
# Total day minutes         164.1
# Total day calls           111.0
# Total day charge           27.9
# Total eve minutes         219.1
# Total eve calls            96.0
# Total eve charge          18.62
# Total night minutes       220.3
# Total night calls         108.0
# Total night charge         9.91
# Total intl minutes         12.3
# Total intl calls              9
# Total intl charge          3.32
# Customer service calls      0.0
# Churn                     False
# Name: MS, dtype: object
# SD
# Account length              163
# Area code                   415
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         197.2
# Total day calls            90.0
# Total day charge          33.52
# Total eve minutes         188.5
# Total eve calls           113.0
# Total eve charge          16.02
# Total night minutes       211.1
# Total night calls          94.0
# Total night charge          9.5
# Total intl minutes          7.8
# Total intl calls              8
# Total intl charge          2.11
# Customer service calls      1.0
# Churn                     False
# Name: SD, dtype: object
# OK
# Account length               52
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         124.9
# Total day calls           131.0
# Total day charge          21.23
# Total eve minutes         300.5
# Total eve calls           118.0
# Total eve charge          25.54
# Total night minutes       192.5
# Total night calls         106.0
# Total night charge         8.66
# Total intl minutes         11.6
# Total intl calls              4
# Total intl charge          3.13
# Customer service calls      2.0
# Churn                     False
# Name: OK, dtype: object
# WY
# Account length               89
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         115.4
# Total day calls            99.0
# Total day charge          19.62
# Total eve minutes         209.9
# Total eve calls           115.0
# Total eve charge          17.84
# Total night minutes       280.9
# Total night calls         112.0
# Total night charge        12.64
# Total intl minutes         15.9
# Total intl calls              6
# Total intl charge          4.29
# Customer service calls      3.0
# Churn                     False
# Name: WY, dtype: object
# GA
# Account length              122
# Area code                   510
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         140.0
# Total day calls           101.0
# Total day charge           23.8
# Total eve minutes         196.4
# Total eve calls            77.0
# Total eve charge          16.69
# Total night minutes       120.1
# Total night calls         133.0
# Total night charge          5.4
# Total intl minutes          9.7
# Total intl calls              4
# Total intl charge          2.62
# Customer service calls      4.0
# Churn                      True
# Name: GA, dtype: object
# VT
# Account length               60
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         193.9
# Total day calls           118.0
# Total day charge          32.96
# Total eve minutes          85.0
# Total eve calls           110.0
# Total eve charge           7.23
# Total night minutes       210.1
# Total night calls         134.0
# Total night charge         9.45
# Total intl minutes         13.2
# Total intl calls              8
# Total intl charge          3.56
# Customer service calls      3.0
# Churn                     False
# Name: VT, dtype: object
# MD
# Account length               62
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         321.1
# Total day calls           105.0
# Total day charge          54.59
# Total eve minutes         265.5
# Total eve calls           122.0
# Total eve charge          22.57
# Total night minutes       180.5
# Total night calls          72.0
# Total night charge         8.12
# Total intl minutes         11.5
# Total intl calls              2
# Total intl charge          3.11
# Customer service calls      4.0
# Churn                      True
# Name: MD, dtype: object
# IN
# Account length              117
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         118.4
# Total day calls           126.0
# Total day charge          20.13
# Total eve minutes         249.3
# Total eve calls            97.0
# Total eve charge          21.19
# Total night minutes       227.0
# Total night calls          56.0
# Total night charge        10.22
# Total intl minutes         13.6
# Total intl calls              3
# Total intl charge          3.67
# Customer service calls      5.0
# Churn                      True
# Name: IN, dtype: object
# WV
# Account length              159
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         169.8
# Total day calls           114.0
# Total day charge          28.87
# Total eve minutes         197.7
# Total eve calls           105.0
# Total eve charge           16.8
# Total night minutes       193.7
# Total night calls          82.0
# Total night charge         8.72
# Total intl minutes         11.6
# Total intl calls              4
# Total intl charge          3.13
# Customer service calls      1.0
# Churn                     False
# Name: WV, dtype: object
# OH
# Account length               78
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         193.4
# Total day calls            99.0
# Total day charge          32.88
# Total eve minutes         116.9
# Total eve calls            88.0
# Total eve charge           9.94
# Total night minutes       243.3
# Total night calls         109.0
# Total night charge        10.95
# Total intl minutes          9.3
# Total intl calls              4
# Total intl charge          2.51
# Customer service calls      2.0
# Churn                     False
# Name: OH, dtype: object
# OH
# Account length               96
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         106.6
# Total day calls           128.0
# Total day charge          18.12
# Total eve minutes         284.8
# Total eve calls            87.0
# Total eve charge          24.21
# Total night minutes       178.9
# Total night calls          92.0
# Total night charge         8.05
# Total intl minutes         14.9
# Total intl calls              7
# Total intl charge          4.02
# Customer service calls      1.0
# Churn                     False
# Name: OH, dtype: object
# SC
# Account length               79
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         134.7
# Total day calls            98.0
# Total day charge           22.9
# Total eve minutes         189.7
# Total eve calls            68.0
# Total eve charge          16.12
# Total night minutes       221.4
# Total night calls         128.0
# Total night charge         9.96
# Total intl minutes         11.8
# Total intl calls              5
# Total intl charge          3.19
# Customer service calls      2.0
# Churn                     False
# Name: SC, dtype: object
# AZ
# Account length              192
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        36
# Total day minutes         156.2
# Total day calls            77.0
# Total day charge          26.55
# Total eve minutes         215.5
# Total eve calls           126.0
# Total eve charge          18.32
# Total night minutes       279.1
# Total night calls          83.0
# Total night charge        12.56
# Total intl minutes          9.9
# Total intl calls              6
# Total intl charge          2.67
# Customer service calls      2.0
# Churn                     False
# Name: AZ, dtype: object
# WV
# Account length               68
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         231.1
# Total day calls            57.0
# Total day charge          39.29
# Total eve minutes         153.4
# Total eve calls            55.0
# Total eve charge          13.04
# Total night minutes       191.3
# Total night calls         123.0
# Total night charge         8.61
# Total intl minutes          9.6
# Total intl calls              4
# Total intl charge          2.59
# Customer service calls      3.0
# Churn                     False
# Name: WV, dtype: object
# RI
# Account length               28
# Area code                   510
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         180.8
# Total day calls           109.0
# Total day charge          30.74
# Total eve minutes         288.8
# Total eve calls            58.0
# Total eve charge          24.55
# Total night minutes       191.9
# Total night calls          91.0
# Total night charge         8.64
# Total intl minutes         14.1
# Total intl calls              6
# Total intl charge          3.81
# Customer service calls      2.0
# Churn                     False
# Name: RI, dtype: object
# CT
# Account length              184
# Area code                   510
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         213.8
# Total day calls           105.0
# Total day charge          36.35
# Total eve minutes         159.6
# Total eve calls            84.0
# Total eve charge          13.57
# Total night minutes       139.2
# Total night calls         137.0
# Total night charge         6.26
# Total intl minutes          5.0
# Total intl calls             10
# Total intl charge          1.35
# Customer service calls      2.0
# Churn                     False
# Name: CT, dtype: object
# TN
# Account length               74
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         234.4
# Total day calls           113.0
# Total day charge          39.85
# Total eve minutes         265.9
# Total eve calls            82.0
# Total eve charge           22.6
# Total night minutes       241.4
# Total night calls          77.0
# Total night charge        10.86
# Total intl minutes         13.7
# Total intl calls              4
# Total intl charge           3.7
# Customer service calls      0.0
# Churn                     False
# Name: TN, dtype: object

# %% [markdown]
# ## Apply

# %%
# data_frame['lower_case_label'] = data_frame[].apply(lower)
# print(data_frame)

# %% [markdown]
# ## Delete data frame object

# %%
del df # delete data frame objet
