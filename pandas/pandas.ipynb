# %% [markdown]
# # CRUD operations with dictionaries in python

# %%
import pandas as pd

# %%
# create a data frame from a CSV
df = pd.read_csv('telco_churn.csv')

# %%
# read a data frame

# display first 5 rows of data
df.head()

# display n rows
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# 1             27.47              195.5            103.0             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# 1                13.7                 3                3.7
#
#    Customer service calls  Churn
# 0                     1.0  False
# 1                     1.0  False

# %%
# display bottom rows, n=5 by default
df.tail(8)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3325    OH              78        408                 No              No
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3325                      0              193.4             99.0
# 3326                      0              106.6            128.0
# 3327                      0              134.7             98.0
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3325             32.88              116.9             88.0              9.94
# 3326             18.12              284.8             87.0             24.21
# 3327             22.90              189.7             68.0             16.12
# 3328             26.55              215.5            126.0             18.32
# 3329             39.29              153.4             55.0             13.04
# 3330             30.74              288.8             58.0             24.55
# 3331             36.35              159.6             84.0             13.57
# 3332             39.85              265.9             82.0             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3325                243.3              109.0               10.95
# 3326                178.9               92.0                8.05
# 3327                221.4              128.0                9.96
# 3328                279.1               83.0               12.56
# 3329                191.3              123.0                8.61
# 3330                191.9               91.0                8.64
# 3331                139.2              137.0                6.26
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3325                 9.3                 4               2.51
# 3326                14.9                 7               4.02
# 3327                11.8                 5               3.19
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3325                     2.0  False
# 3326                     1.0  False
# 3327                     2.0  False
# 3328                     2.0  False
# 3329                     3.0  False
# 3330                     2.0  False
# 3331                     2.0  False
# 3332                     0.0  False

# %%
# create a dataframe from a dictionary

# %%
dict = {'col_1': [1, 2, 3], 'col_2': [4, 5, 6], 'col_3': [7, 8, 9]}

# %%
dict_df = pd.DataFrame(dict)
dict_df.head()
# Out:
#    col_1  col_2  col_3
# 0      1      4      7
# 1      2      5      8
# 2      3      6      9

# %%
# show columns
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.State # access a column whose name is without spaces
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df['Account length'] # access a column with spaces in the column name
# Out:
# 0       128
# 1       107
# 2       137
# 3        84
# 4        75
#        ...
# 3328    192
# 3329     68
# 3330     28
# 3331    184
# 3332     74
# Name: Account length, Length: 3333, dtype: int64

# %%
df[['State', 'Account length']] # access multiple columns
# Out:
#      State  Account length
# 0       KS             128
# 1       OH             107
# 2       NJ             137
# 3       OH              84
# 4       OK              75
# ...    ...             ...
# 3328    AZ             192
# 3329    WV              68
# 3330    RI              28
# 3331    CT             184
# 3332    TN              74
#
# [3333 rows x 2 columns]

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# std          20.057356          9.255987          50.676652        19.932115
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.420000         166.600000        87.000000
# 50%         101.000000         30.500000         201.400000       100.000000
# 75%         114.000000         36.780000         235.325000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        Total eve charge  Total night minutes  Total night calls  \
# count       3333.000000          3333.000000        3332.000000
# mean          17.083540           200.872037         100.115246
# std            4.310668            50.573847          19.566710
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.000000          87.000000
# 50%           17.120000           201.200000         100.000000
# 75%           20.000000           235.300000         113.000000
# max           30.910000           395.000000         175.000000
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count         3333.000000         3333.000000       3333.000000
# mean             9.039325           10.237294          4.479448
# std              2.275873            2.791840          2.461214
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.050000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        Total intl charge  Customer service calls
# count        3328.000000             3328.000000
# mean            2.764588                1.563101
# std             0.754086                1.315870
# min             0.000000                0.000000
# 25%             2.300000                1.000000
# 50%             2.780000                1.000000
# 75%             3.270000                2.000000
# max             5.400000                9.000000

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3325
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2842

# %%
df.State.unique() # filter on column
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df[df['International plan'] == 'No'] # conditionally filter on column
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# 6                        24              218.2             88.0
# 8                         0              184.5             97.0
# ...                     ...                ...              ...
# 3327                      0              134.7             98.0
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4             99.0             16.78
# 1                27.47              195.5            103.0             16.62
# 2                41.38              121.2            110.0             10.30
# 6                37.09              348.5            108.0             29.62
# 8                31.37              351.6             80.0             29.89
# ...                ...                ...              ...               ...
# 3327             22.90              189.7             68.0             16.12
# 3328             26.55              215.5            126.0             18.32
# 3329             39.29              153.4             55.0             13.04
# 3330             30.74              288.8             58.0             24.55
# 3332             39.85              265.9             82.0             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7               91.0               11.01
# 1                   254.4              103.0               11.45
# 2                   162.6              104.0                7.32
# 6                   212.6              118.0                9.57
# 8                   215.8               90.0                9.71
# ...                   ...                ...                 ...
# 3327                221.4              128.0                9.96
# 3328                279.1               83.0               12.56
# 3329                191.3              123.0                8.61
# 3330                191.9               91.0                8.64
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 6                    7.5                 7               2.03
# 8                    8.7                 4               2.35
# ...                  ...               ...                ...
# 3327                11.8                 5               3.19
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                        1.0  False
# 1                        1.0  False
# 2                        0.0  False
# 6                        3.0    NaN
# 8                        1.0  False
# ...                      ...    ...
# 3327                     2.0  False
# 3328                     2.0  False
# 3329                     3.0  False
# 3330                     2.0  False
# 3332                     0.0  False
#
# [3010 rows x 20 columns]

# %%
# filter with multiple conditions
# isolate boolean values with parentheses
# use & for AND
df[(df['International plan'] == 'No') & (df.Churn == True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 48      ID             119        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3280    AR              76        408                 No              No
# 3287    KS             170        415                 No             Yes
# 3301    CA              84        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 10                        0              129.1            137.0
# 15                        0                NaN              NaN
# 21                        0                NaN              NaN
# 33                        0              249.6            118.0
# 48                        0              159.1            114.0
# ...                     ...                ...              ...
# 3280                      0              107.3            140.0
# 3287                     42              199.5            119.0
# 3301                      0              280.0            113.0
# 3322                      0              321.1            105.0
# 3323                      0              118.4            126.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 10               21.95              228.5             83.0             19.42
# 15                 NaN              317.8             97.0             27.01
# 21                 NaN              169.9            121.0             14.44
# 33                 NaN                NaN              NaN             21.45
# 48               27.05              231.3            117.0             19.66
# ...                ...                ...              ...               ...
# 3280             18.24              238.2            133.0             20.25
# 3287             33.92              135.0             90.0             11.48
# 3301             47.60              202.2             90.0             17.19
# 3322             54.59              265.5            122.0             22.57
# 3323             20.13              249.3             97.0             21.19
#
#       Total night minutes  Total night calls  Total night charge  \
# 10                  208.8              111.0                9.40
# 15                  160.6              128.0                7.23
# 21                  209.6               64.0                9.43
# 33                  280.2               90.0               12.61
# 48                  143.2               91.0                6.44
# ...                   ...                ...                 ...
# 3280                271.8              116.0               12.23
# 3287                184.6               49.0                8.31
# 3301                156.8              103.0                7.06
# 3322                180.5               72.0                8.12
# 3323                227.0               56.0               10.22
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 10                  12.7                 6               3.43
# 15                   5.4                 9               1.46
# 21                   5.7                 6               1.54
# 33                  11.8                 3               3.19
# 48                   8.8                 3               2.38
# ...                  ...               ...                ...
# 3280                10.0                 3               2.70
# 3287                10.9                 3               2.94
# 3301                10.4                 4               2.81
# 3322                11.5                 2               3.11
# 3323                13.6                 3               3.67
#
#       Customer service calls Churn
# 10                       4.0  True
# 15                       4.0  True
# 21                       5.0  True
# 33                       1.0  True
# 48                       5.0  True
# ...                      ...   ...
# 3280                     4.0  True
# 3287                     4.0  True
# 3301                     0.0  True
# 3322                     4.0  True
# 3323                     5.0  True
#
# [346 rows x 20 columns]

# %%
# iloc method
# integer location based index
df.iloc[14] # access the 15th row of a data frame
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
df.iloc[14, 0] #access the 15th row, first column
# Out:
# 'IA'

# %%
# slicing
df.iloc[22:33] # access rows 22-33, excluding
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 22    AZ             130        415                 No              No
# 23    SC             111        415                 No              No
# 24    VA             132        510                 No              No
# 25    NE             174        415                 No              No
# 26    WY              57        408                 No             Yes
# 27    MT              54        408                 No              No
# 28    MO              20        415                 No              No
# 29    HI              49        510                 No              No
# 30    IL             142        415                 No              No
# 31    NH              75        510                 No              No
# 32    LA             172        408                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 22                      0              183.0            112.0
# 23                      0              110.4            103.0
# 24                      0               81.1             86.0
# 25                      0              124.3             76.0
# 26                     39              213.0            115.0
# 27                      0              134.3             73.0
# 28                      0              190.0            109.0
# 29                      0              119.3            117.0
# 30                      0               84.8             95.0
# 31                      0              226.1            105.0
# 32                      0              212.0            121.0
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 22             31.11               72.9             99.0              6.20
# 23             18.77              137.3            102.0             11.67
# 24             13.79              245.2             72.0             20.84
# 25             21.13              277.1            112.0             23.55
# 26             36.21              191.1            112.0             16.24
# 27             22.83              155.5            100.0             13.22
# 28             32.30              258.2             84.0             21.95
# 29             20.28              215.1            109.0             18.28
# 30             14.42              136.7             63.0             11.62
# 31               NaN                NaN              NaN             17.13
# 32               NaN                NaN              NaN              2.65
#
#     Total night minutes  Total night calls  Total night charge  \
# 22                181.8               78.0                8.18
# 23                189.6              105.0                8.53
# 24                237.0              115.0               10.67
# 25                250.7              115.0               11.28
# 26                182.7              115.0                8.22
# 27                102.1               68.0                4.59
# 28                181.5              102.0                8.17
# 29                178.7               90.0                8.04
# 30                250.5              148.0               11.27
# 31                246.2               98.0               11.08
# 32                293.3               78.0               13.20
#
#     Total intl minutes  Total intl calls  Total intl charge  \
# 22                 9.5                19               2.57
# 23                 7.7                 6               2.08
# 24                10.3                 2               2.78
# 25                15.5                 5               4.19
# 26                 9.5                 3               2.57
# 27                14.7                 4               3.97
# 28                 6.3                 6               1.70
# 29                11.1                 1               3.00
# 30                14.2                 6               3.83
# 31                10.3                 5               2.78
# 32                12.6                10               3.40
#
#     Customer service calls  Churn
# 22                     0.0    NaN
# 23                     2.0  False
# 24                     0.0  False
# 25                     3.0  False
# 26                     0.0  False
# 27                     3.0  False
# 28                     0.0  False
# 29                     1.0    NaN
# 30                     2.0  False
# 31                     1.0  False
# 32                     3.0  False

# %%
state = df.copy()
state.set_index('State', inplace=True) # set a colummn value as index rather than integer
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# KS                45.07              197.4             99.0             16.78
# OH                27.47              195.5            103.0             16.62
# NJ                41.38              121.2            110.0             10.30
# OH                50.90               61.9             88.0              5.26
# OK                28.34              148.3            122.0             12.61
#
#        Total night minutes  Total night calls  Total night charge  \
# State
# KS                   244.7               91.0               11.01
# OH                   254.4              103.0               11.45
# NJ                   162.6              104.0                7.32
# OH                   196.9               89.0                8.86
# OK                   186.9              121.0                8.41
#
#        Total intl minutes  Total intl calls  Total intl charge  \
# State
# KS                   10.0                 3               2.70
# OH                   13.7                 3               3.70
# NJ                   12.2                 5               3.29
# OH                    6.6                 7               1.78
# OK                   10.1                 3               2.73
#
#        Customer service calls  Churn
# State
# KS                        1.0  False
# OH                        1.0  False
# NJ                        0.0  False
# OH                        2.0  False
# OK                        3.0  False

# %%
state.loc['OH'] # filter by location of non-integer value
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                107        415                 No             Yes
# OH                 84        408                Yes              No
# OH                 65        408                 No              No
# OH                 83        415                 No              No
# OH                 63        415                Yes             Yes
# ...               ...        ...                ...             ...
# OH                160        415                 No              No
# OH                 88        408                 No              No
# OH                106        415                 No             Yes
# OH                 78        408                 No              No
# OH                 96        415                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        26              161.6            123.0
# OH                         0              299.4             71.0
# OH                         0              187.9            116.0
# OH                         0              337.4            120.0
# OH                        36              199.0            110.0
# ...                      ...                ...              ...
# OH                         0              206.3             66.0
# OH                         0              274.6            105.0
# OH                        30              220.1            105.0
# OH                         0              193.4             99.0
# OH                         0              106.6            128.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# OH                27.47              195.5            103.0             16.62
# OH                50.90               61.9             88.0              5.26
# OH                31.94              157.6            117.0             13.40
# OH                57.36              227.4            116.0             19.33
# OH                33.83              291.3            111.0             24.76
# ...                 ...                ...              ...               ...
# OH                35.07              241.1            109.0             20.49
# OH                46.68              161.1            121.0             13.69
# OH                37.42              222.2            109.0             18.89
# OH                32.88              116.9             88.0              9.94
# OH                18.12              284.8             87.0             24.21
#
#        Total night minutes  Total night calls  Total night charge  \
# State
# OH                   254.4              103.0               11.45
# OH                   196.9               89.0                8.86
# OH                   227.3               86.0               10.23
# OH                   153.9              114.0                6.93
# OH                   197.6               92.0                8.89
# ...                    ...                ...                 ...
# OH                   227.8              102.0               10.25
# OH                   194.4              123.0                8.75
# OH                   158.4               96.0                7.13
# OH                   243.3              109.0               10.95
# OH                   178.9               92.0                8.05
#
#        Total intl minutes  Total intl calls  Total intl charge  \
# State
# OH                   13.7                 3               3.70
# OH                    6.6                 7               1.78
# OH                    7.5                 6               2.03
# OH                   15.8                 7               4.27
# OH                   11.0                 6               2.97
# ...                   ...               ...                ...
# OH                   11.7                 6               3.16
# OH                    9.2                 4               2.48
# OH                   13.1                 8               3.54
# OH                    9.3                 4               2.51
# OH                   14.9                 7               4.02
#
#        Customer service calls  Churn
# State
# OH                        1.0  False
# OH                        2.0  False
# OH                        1.0  False
# OH                        0.0   True
# OH                        1.0  False
# ...                       ...    ...
# OH                        0.0  False
# OH                        2.0  False
# OH                        0.0  False
# OH                        2.0  False
# OH                        1.0  False
#
# [78 rows x 19 columns]

# %%
df.isnull().sum() # find the total null-value occurrences
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True) # drop null values in place
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.drop('Area code', axis=1) # drop a column along one axis
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# 3                         0              299.4             71.0
# 4                         0              166.7            113.0
# ...                     ...                ...              ...
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4             99.0             16.78
# 1                27.47              195.5            103.0             16.62
# 2                41.38              121.2            110.0             10.30
# 3                50.90               61.9             88.0              5.26
# 4                28.34              148.3            122.0             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5            126.0             18.32
# 3329             39.29              153.4             55.0             13.04
# 3330             30.74              288.8             58.0             24.55
# 3331             36.35              159.6             84.0             13.57
# 3332             39.85              265.9             82.0             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7               91.0               11.01
# 1                   254.4              103.0               11.45
# 2                   162.6              104.0                7.32
# 3                   196.9               89.0                8.86
# 4                   186.9              121.0                8.41
# ...                   ...                ...                 ...
# 3328                279.1               83.0               12.56
# 3329                191.3              123.0                8.61
# 3330                191.9               91.0                8.64
# 3331                139.2              137.0                6.26
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                        1.0  False
# 1                        1.0  False
# 2                        0.0  False
# 3                        2.0  False
# 4                        3.0  False
# ...                      ...    ...
# 3328                     2.0  False
# 3329                     3.0  False
# 3330                     2.0  False
# 3331                     2.0  False
# 3332                     0.0  False
#
# [3307 rows x 19 columns]

# %%
df['New Column'] = df['Total night minutes'] + df['Total intl minutes']

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
# 2             41.38              121.2  ...             10.30
# 3             50.90               61.9  ...              5.26
# 4             28.34              148.3  ...             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn New Column
# 0                     1.0  False      254.7
# 1                     1.0  False      268.1
# 2                     0.0  False      174.8
# 3                     2.0  False      203.5
# 4                     3.0  False      197.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Update all rows in a column

# %%
df['New Column'] = 100
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
# 2             41.38              121.2  ...             10.30
# 3             50.90               61.9  ...              5.26
# 4             28.34              148.3  ...             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn New Column
# 0                     1.0  False        100
# 1                     1.0  False        100
# 2                     0.0  False        100
# 3                     2.0  False        100
# 4                     3.0  False        100
#
# [5 rows x 21 columns]

# %% [markdown]
# ### iloc method

# %%
df.iloc[0, -1] = 10 # update a value at a particular location
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
# 2             41.38              121.2  ...             10.30
# 3             50.90               61.9  ...              5.26
# 4             28.34              148.3  ...             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn New Column
# 0                     1.0  False         10
# 1                     1.0  False        100
# 2                     0.0  False        100
# 3                     2.0  False        100
# 4                     3.0  False        100
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Apply method

# %%
df['Churn Binary'] = df['Churn'].apply(lambda x: 1 if x==True else 0)
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             27.47              195.5  ...                254.4
# 2             41.38              121.2  ...                162.6
# 3             50.90               61.9  ...                196.9
# 4             28.34              148.3  ...                186.9
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0               91.0               11.01                10.0
# 1              103.0               11.45                13.7
# 2              104.0                7.32                12.2
# 3               89.0                8.86                 6.6
# 4              121.0                8.41                10.1
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3               2.70                     1.0  False
# 1                 3               3.70                     1.0  False
# 2                 5               3.29                     0.0  False
# 3                 7               1.78                     2.0  False
# 4                 3               2.73                     3.0  False
#
#    New Column Churn Binary
# 0          10            0
# 1         100            0
# 2         100            0
# 3         100            0
# 4         100            0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Output file

# %%
df.to_csv('Output.csv')

# %%
df.to_json('Output.json')

# %% [markdown]
# ### Looping over data frames

# %%
data_frame = pd.read_csv('telco_churn.csv', index_col = 0)
print(data_frame)
for lab, row in data_frame.head().iterrows():
    print(lab)
    print(row)
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
# ...               ...        ...                ...             ...
# AZ                192        415                 No             Yes
# WV                 68        415                 No              No
# RI                 28        510                 No              No
# CT                184        510                Yes              No
# TN                 74        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
# ...                      ...                ...              ...
# AZ                        36              156.2             77.0
# WV                         0              231.1             57.0
# RI                         0              180.8            109.0
# CT                         0              213.8            105.0
# TN                        25              234.4            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# KS                45.07              197.4             99.0             16.78
# OH                27.47              195.5            103.0             16.62
# NJ                41.38              121.2            110.0             10.30
# OH                50.90               61.9             88.0              5.26
# OK                28.34              148.3            122.0             12.61
# ...                 ...                ...              ...               ...
# AZ                26.55              215.5            126.0             18.32
# WV                39.29              153.4             55.0             13.04
# RI                30.74              288.8             58.0             24.55
# CT                36.35              159.6             84.0             13.57
# TN                39.85              265.9             82.0             22.60
#
#        Total night minutes  Total night calls  Total night charge  \
# State
# KS                   244.7               91.0               11.01
# OH                   254.4              103.0               11.45
# NJ                   162.6              104.0                7.32
# OH                   196.9               89.0                8.86
# OK                   186.9              121.0                8.41
# ...                    ...                ...                 ...
# AZ                   279.1               83.0               12.56
# WV                   191.3              123.0                8.61
# RI                   191.9               91.0                8.64
# CT                   139.2              137.0                6.26
# TN                   241.4               77.0               10.86
#
#        Total intl minutes  Total intl calls  Total intl charge  \
# State
# KS                   10.0                 3               2.70
# OH                   13.7                 3               3.70
# NJ                   12.2                 5               3.29
# OH                    6.6                 7               1.78
# OK                   10.1                 3               2.73
# ...                   ...               ...                ...
# AZ                    9.9                 6               2.67
# WV                    9.6                 4               2.59
# RI                   14.1                 6               3.81
# CT                    5.0                10               1.35
# TN                   13.7                 4               3.70
#
#        Customer service calls  Churn
# State
# KS                        1.0  False
# OH                        1.0  False
# NJ                        0.0  False
# OH                        2.0  False
# OK                        3.0  False
# ...                       ...    ...
# AZ                        2.0  False
# WV                        3.0  False
# RI                        2.0  False
# CT                        2.0  False
# TN                        0.0  False
#
# [3333 rows x 19 columns]
# KS
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         265.1
# Total day calls           110.0
# Total day charge          45.07
# Total eve minutes         197.4
# Total eve calls            99.0
# Total eve charge          16.78
# Total night minutes       244.7
# Total night calls          91.0
# Total night charge        11.01
# Total intl minutes         10.0
# Total intl calls              3
# Total intl charge           2.7
# Customer service calls      1.0
# Churn                     False
# Name: KS, dtype: object
# OH
# Account length              107
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        26
# Total day minutes         161.6
# Total day calls           123.0
# Total day charge          27.47
# Total eve minutes         195.5
# Total eve calls           103.0
# Total eve charge          16.62
# Total night minutes       254.4
# Total night calls         103.0
# Total night charge        11.45
# Total intl minutes         13.7
# Total intl calls              3
# Total intl charge           3.7
# Customer service calls      1.0
# Churn                     False
# Name: OH, dtype: object
# NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls           114.0
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls           110.0
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls         104.0
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls      0.0
# Churn                     False
# Name: NJ, dtype: object
# OH
# Account length               84
# Area code                   408
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         299.4
# Total day calls            71.0
# Total day charge           50.9
# Total eve minutes          61.9
# Total eve calls            88.0
# Total eve charge           5.26
# Total night minutes       196.9
# Total night calls          89.0
# Total night charge         8.86
# Total intl minutes          6.6
# Total intl calls              7
# Total intl charge          1.78
# Customer service calls      2.0
# Churn                     False
# Name: OH, dtype: object
# OK
# Account length               75
# Area code                   415
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         166.7
# Total day calls           113.0
# Total day charge          28.34
# Total eve minutes         148.3
# Total eve calls           122.0
# Total eve charge          12.61
# Total night minutes       186.9
# Total night calls         121.0
# Total night charge         8.41
# Total intl minutes         10.1
# Total intl calls              3
# Total intl charge          2.73
# Customer service calls      3.0
# Churn                     False
# Name: OK, dtype: object

# %% [markdown]
# ## Apply

# %%
# data_frame['lower_case_label'] = data_frame[].apply(lower)
# print(data_frame)

# %% [markdown]
# ## Delete data frame object

# %%
del df # delete data frame objet

# %% [markdown]
# # Dates and times

# %% [markdown]
# Parse dates automatically while creating a dataframe from a csv

# %%
import pandas as pd

holidays = pd.read_csv('holidays.csv', parse_dates = ['Start Date', 'End Date']) # date-containing column names
holidays
# Out:
#   Start Date   End Date            Event Name         Location
# 0 2023-01-01 2023-01-05  New Year Celebration         New York
# 1 2023-02-14 2023-02-20  Valentine's Day Trip            Paris
# 2 2023-07-04 2023-07-07      Independence Day  Washington D.C.
# 3 2023-12-25 2023-12-30    Christmas Vacation           London

# %% [markdown]
# If automatic formatting fails, a manual option is available

# %%
holidays['Start Date'] = pd.to_datetime(holidays['Start Date'], format = '%Y-%m-%d')
holidays['Start Date']
# Out:
# 0   2023-01-01
# 1   2023-02-14
# 2   2023-07-04
# 3   2023-12-25
# Name: Start Date, dtype: datetime64[ns]

# %% [markdown]
# ## Time arithmetic

# %%
holidays['Duration'] = holidays['End Date'] - holidays['Start Date']
print(holidays)
# Out:
#   Start Date   End Date            Event Name         Location Duration
# 0 2023-01-01 2023-01-05  New Year Celebration         New York   4 days
# 1 2023-02-14 2023-02-20  Valentine's Day Trip            Paris   6 days
# 2 2023-07-04 2023-07-07      Independence Day  Washington D.C.   3 days
# 3 2023-12-25 2023-12-30    Christmas Vacation           London   5 days

# %%
# backward slash supports line continuation
duration_in_seconds = holidays['Duration']\
    .dt.total_seconds()\
    .head(5)

print(duration_in_seconds)
# Out:
# 0    345600.0
# 1    518400.0
# 2    259200.0
# 3    432000.0
# Name: Duration, dtype: float64

# %% [markdown]
# ## Summarizing data

# %% [markdown]
# ### Mean

# %%
holidays['Duration'].mean()
# Out:
# Timedelta('4 days 12:00:00')

# %% [markdown]
# ### Sum

# %%
holidays['Duration'].sum()
# Out:
# Timedelta('18 days 00:00:00')

# %% [markdown]
# ### Datetime math with pandas

# %%
from datetime import timedelta

year = timedelta(days=365)
on_holiday = holidays['Duration'].sum()
print('On holiday', int(on_holiday / year * 100), '% of the year')
# Out:
# On holiday 4 % of the year

# %%
df = pd.read_csv('telco_churn.csv')

print(df['Churn'].value_counts())
# Out:
# Churn
# False    2842
# True      483
# Name: count, dtype: int64

# %%
churn = df['Churn'].value_counts() / len(df)
print(churn)
# Out:
# Churn
# False    0.852685
# True     0.144914
# Name: count, dtype: float64

# %% [markdown]
# ## Grouping rows

# %% [markdown]
# ### Group by value

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# 1             27.47              195.5            103.0             16.62
# 2             41.38              121.2            110.0             10.30
# 3             50.90               61.9             88.0              5.26
# 4             28.34              148.3            122.0             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                     1.0  False
# 1                     1.0  False
# 2                     0.0  False
# 3                     2.0  False
# 4                     3.0  False

# %% [markdown]
# ### Group methods

# %%
minutes_by_state = df.groupby('State')['Total day minutes']
state_means = minutes_by_state.mean().head()
print(state_means)
# Out:
# State
# AK    178.384615
# AL    186.010000
# AR    176.116364
# AZ    171.604688
# CA    183.564706
# Name: Total day minutes, dtype: float64

# %%
s = minutes_by_state.size()
print(s.head())
# Out:
# State
# AK    52
# AL    80
# AR    55
# AZ    64
# CA    34
# Name: Total day minutes, dtype: int64

# %%
f = minutes_by_state.first()
print(f.head())
# Out:
# State
# AK    146.3
# AL    223.4
# AR    124.8
# AZ    183.0
# CA    268.6
# Name: Total day minutes, dtype: float64

# %% [markdown]
# ### Resample

# %%
holidays.resample('ME', on='Start Date')['Duration'].mean()
# Out:
# Start Date
# 2023-01-31   4 days
# 2023-02-28   6 days
# 2023-03-31      NaT
# 2023-04-30      NaT
# 2023-05-31      NaT
# 2023-06-30      NaT
# 2023-07-31   3 days
# 2023-08-31      NaT
# 2023-09-30      NaT
# 2023-10-31      NaT
# 2023-11-30      NaT
# 2023-12-31   5 days
# Freq: ME, Name: Duration, dtype: timedelta64[ns]

# %%
# help(df.resample)

# %% [markdown]
# ## Timezones

# %%
holidays
# Out:
#   Start Date   End Date            Event Name         Location Duration
# 0 2023-01-01 2023-01-05  New Year Celebration         New York   4 days
# 1 2023-02-14 2023-02-20  Valentine's Day Trip            Paris   6 days
# 2 2023-07-04 2023-07-07      Independence Day  Washington D.C.   3 days
# 3 2023-12-25 2023-12-30    Christmas Vacation           London   5 days

# %% [markdown]
# ## Set a timezone

# %%
holidays['Start Date'].dt.tz_localize('America/New_York')
# Out:
# 0   2023-01-01 00:00:00-05:00
# 1   2023-02-14 00:00:00-05:00
# 2   2023-07-04 00:00:00-04:00
# 3   2023-12-25 00:00:00-05:00
# Name: Start Date, dtype: datetime64[ns, America/New_York]

# %% [markdown]
# ## Convert a timezone

# %%
holidays['Start Date'] = holidays['Start Date'].dt.tz_localize('America/New_York')
print(holidays['Start Date'])

holidays['Start Date'] = holidays['Start Date'].dt.tz_convert('Europe/London')
print(holidays['Start Date'])
# Out:
# 0   2023-01-01 00:00:00-05:00
# 1   2023-02-14 00:00:00-05:00
# 2   2023-07-04 00:00:00-04:00
# 3   2023-12-25 00:00:00-05:00
# Name: Start Date, dtype: datetime64[ns, America/New_York]
# 0   2023-01-01 05:00:00+00:00
# 1   2023-02-14 05:00:00+00:00
# 2   2023-07-04 05:00:00+01:00
# 3   2023-12-25 05:00:00+00:00
# Name: Start Date, dtype: datetime64[ns, Europe/London]

# %% [markdown]
# ## Handle ambiguous datetimes

# %%
# Daylight savings-aware UTC
holidays['End Date'].dt.tz_localize('America/New_York', ambiguous='NaT') # not a time
# Out:
# 0   2023-01-05 00:00:00-05:00
# 1   2023-02-20 00:00:00-05:00
# 2   2023-07-07 00:00:00-04:00
# 3   2023-12-30 00:00:00-05:00
# Name: End Date, dtype: datetime64[ns, America/New_York]

# %% [markdown]
# ## Access datetime components

# %%
print(holidays['Start Date'].dt.year)
print(holidays['Start Date'].dt.month)
# Out:
# 0    2023
# 1    2023
# 2    2023
# 3    2023
# Name: Start Date, dtype: int32
# 0     1
# 1     2
# 2     7
# 3    12
# Name: Start Date, dtype: int32

# %% [markdown]
# ## Helpful methods

# %% [markdown]
# ### Day name

# %%
holidays['Start Date'].dt.day_name()
# Out:
# 0     Sunday
# 1    Tuesday
# 2    Tuesday
# 3     Monday
# Name: Start Date, dtype: object

# %% [markdown]
# ### Shift

# %%
holidays
# Out:
#                  Start Date   End Date            Event Name         Location  \
# 0 2023-01-01 05:00:00+00:00 2023-01-05  New Year Celebration         New York
# 1 2023-02-14 05:00:00+00:00 2023-02-20  Valentine's Day Trip            Paris
# 2 2023-07-04 05:00:00+01:00 2023-07-07      Independence Day  Washington D.C.
# 3 2023-12-25 05:00:00+00:00 2023-12-30    Christmas Vacation           London
#
#   Duration
# 0   4 days
# 1   6 days
# 2   3 days
# 3   5 days

# %%
holidays['End Date'].shift(1)
# Out:
# 0          NaT
# 1   2023-01-05
# 2   2023-02-20
# 3   2023-07-07
# Name: End Date, dtype: datetime64[ns]

# %%
holidays['End Date'].shift(3)
# Out:
# 0          NaT
# 1          NaT
# 2          NaT
# 3   2023-01-05
# Name: End Date, dtype: datetime64[ns]

# %% [markdown]
# ## Pivot Tables

# %%
import numpy as np
holidays
# Out:
#                  Start Date   End Date            Event Name         Location  \
# 0 2023-01-01 05:00:00+00:00 2023-01-05  New Year Celebration         New York
# 1 2023-02-14 05:00:00+00:00 2023-02-20  Valentine's Day Trip            Paris
# 2 2023-07-04 05:00:00+01:00 2023-07-07      Independence Day  Washington D.C.
# 3 2023-12-25 05:00:00+00:00 2023-12-30    Christmas Vacation           London
#
#   Duration
# 0   4 days
# 1   6 days
# 2   3 days
# 3   5 days

# %%
holidays.pivot_table(values = 'Event Name', index='Duration', aggfunc=np.median)
# Out:
# /var/folders/vk/vppwqjsj17g81tdph5mty6xw0000gn/T/ipykernel_13325/3058802696.py:1: FutureWarning: The provided callable <function median at 0x1047a58a0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   holidays.pivot_table(values = 'Event Name', index='Duration', aggfunc=np.median)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2534, in GroupBy.median.<locals>.<lambda>(x)
#    2461 """
#    2462 Compute median of groups, excluding missing values.
#    2463
#    (...)
#    2530 Freq: MS, dtype: float64
#    2531 """
#    2532 result = self._cython_agg_general(
#    2533     "median",
# -> 2534     alt=lambda x: Series(x, copy=False).median(numeric_only=numeric_only),
#    2535     numeric_only=numeric_only,
#    2536 )
#    2537 return result.__finalize__(self.obj, method="groupby")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:6559, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6551 @doc(make_doc("median", ndim=1))
#    6552 def median(
#    6553     self,
#    (...)
#    6557     **kwargs,
#    6558 ):
# -> 6559     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
#   12430 ) -> Series | float:
# > 12431     return self._stat_function(
#   12432         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#
# TypeError: Cannot convert ['Independence Day'] to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 holidays.pivot_table(values = 'Event Name', index='Duration', aggfunc=np.median)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
#    9517         dropna=dropna,
#    9518         margins_name=margins_name,
#    9519         observed=observed,
#    9520         sort=sort,
#    9521     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:183, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     173 if observed is lib.no_default and any(
#     174     ping._passed_categorical for ping in grouped._grouper.groupings
#     175 ):
#     176     warnings.warn(
#     177         "The default value of observed=False is deprecated and will change "
#     178         "to observed=True in a future version of pandas. Specify "
#    (...)
#     181         stacklevel=find_stack_level(),
#     182     )
# --> 183 agged = grouped.agg(aggfunc)
#     185 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     186     agged = agged.dropna(how="all")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:199, in Apply.agg(self)
#     197     if f and not args and not kwargs:
#     198         warn_alias_replacement(obj, func, f)
# --> 199         return getattr(obj, f)()
#     201 # caller can react
#     202 return None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2532, in GroupBy.median(self, numeric_only)
#    2459 @final
#    2460 def median(self, numeric_only: bool = False) -> NDFrameT:
#    2461     """
#    2462     Compute median of groups, excluding missing values.
#    2463
#    (...)
#    2530     Freq: MS, dtype: float64
#    2531     """
# -> 2532     result = self._cython_agg_general(
#    2533         "median",
#    2534         alt=lambda x: Series(x, copy=False).median(numeric_only=numeric_only),
#    2535         numeric_only=numeric_only,
#    2536     )
#    2537     return result.__finalize__(self.obj, method="groupby")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->median,dtype->object]
